# %% [markdown]
# # Jupyter安装

# %% [markdown]
# pip install notebook

# %% [markdown]
# Jupyter Notebook，以前称为IPython Notebook，是一种灵活的python编程工具，可以用来创建可读的分析。
# 在Jupyter Notebook上可以将代码、图像、注释、公式和可视化结果保存在一起。

# %% [markdown]
#  A：在当前单元格上方插入新单元格
#  B：在当前单元格下方插入新单元格
# X：剪切选中的单元
#  Shift +V：在上方粘贴单元
#  D+D:删除

# %% [markdown]
# Jupyter Notebook 有两种键盘输入模式。
# 编辑模式，允许用户往单元中键入代码或文本；这时的单元框线是绿色的。
# 命令模式，键盘输入运行程序命令；这时的单元框线是灰色。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Markdown语法

# %% [markdown]
# https://markdown.com.cn/intro.html

# %% [markdown]
# ## 标题

# %% [markdown]
# 要创建标题，请在单词或短语前面添加井号 (#) 。# 的数量代表了标题的级别。例如，添加三个 # 表示创建一个三级标题 (<h3>) (例如：### My Header)。

# %% [markdown]
# ## 段落

# %% [markdown]
# 要创建段落，请使用空白行将一行或多行文本进行分隔。

# %% [markdown]
# ## 换行

# %% [markdown]
# 在一行的末尾添加两个或多个空格，然后按回车键,即可创建一个换行(<br>)。

# %% [markdown]
# ## 强调

# %% [markdown]
# 粗体（Bold） Love **is** bold
# 斜体（Italic） Italicized text is the *cat's meow*.

# %% [markdown]
# ## 引用

# %% [markdown]
# > Dorothy followed her through many of the beautiful rooms in her castle.

# %% [markdown]
# 嵌套块引用

# %% [markdown]
# > #### The quarterly results look great!
# >
# > - Revenue was off the chart.
# > - Profits were higher than ever.
# >
# >  *Everything* is going according to **plan**.

# %% [markdown]
# ## 列表

# %% [markdown]
# 列表分有序表和无需表

# %% [markdown]
# ### 有序

# %% [markdown]
# 要创建有序列表，请在每个列表项前添加数字并紧跟一个英文句点。数字不必按数学顺序排列，但是列表应当以数字 1 起始。

# %% [markdown]
# 1. First item
# 2. Second item
# 3. Third item
# 4. Fourth item
# 1. bjh

# %% [markdown]
# ### 无序

# %% [markdown]
# 要创建无序列表，请在每个列表项前面添加破折号 (-)、星号 (*) 或加号 (+) 。缩进一个或多个列表项可创建嵌套列表。

# %% [markdown]
# - First item
# - Second item
# - Third item
# - Fourth item

# %% [markdown]
# ## 代码

# %% [markdown]
# 要将单词或短语表示为代码，请将其包裹在反引号 (`) 中。

# %% [markdown]
# At the command prompt, type `nano`.

# %% [markdown]
# ``Use `code` in your Markdown file.``

# %% [markdown]
# ## 分割线

# %% [markdown]
# 要创建分隔线，请在单独一行上使用三个或多个星号 (***)、破折号 (---) 或下划线 (___) ，并且不能包含其他内容。

# %% [markdown]
# ---

# %% [markdown]
# ## 链接

# %% [markdown]
# 链接文本放在中括号内，链接地址放在后面的括号中，链接title可选。
#
# 超链接Markdown语法代码：[超链接显示名](超链接地址 "超链接title")
#
# 使用尖括号可以很方便地把URL或者email地址变成可点击的链接。

# %% [markdown]
# 这是一个链接 [Markdown语法](https://markdown.com.cn "人工智能培训")。

# %% [markdown]
# ## 图片

# %% [markdown]
# 要添加图像，请使用感叹号 (!), 然后在方括号增加替代文本，图片链接放在圆括号里，括号里的链接后可以增加一个可选的图片标题文本。
#
# 插入图片Markdown语法代码：![图片alt](图片链接 "图片title")。

# %% [markdown]
# ![沙漠中的岩石图片](/assets/img/shiprock.jpg "Shiprock")

# %% [markdown]
# ## 转义字符

# %% [markdown]
# 要显示原本用于格式化 Markdown 文档的字符，请在字符前面添加反斜杠字符 \ 。

# %% [markdown]
# \* Without the backslash, this would be a bullet in an unordered list.

# %% [markdown]
# ## 其他

# %% [markdown]
# - [x] Write the press release
# - [ ] Update the website
# - [ ] Contact the media

# %% [markdown]
# ## 第二章 Python 基本元素：数字、字符串和变量

# %% [markdown]
# ### 2.1　变量、名字和对象

# %% [markdown]
# 所谓'变量'就是在程序中为了方便地引用内存中的值而为它取的名称。

# %% [markdown]
# Python 里所有数据——布尔值、整数、浮点数、字符串，甚至大型数据结构、函数以及程序——都是以对象（object）的形式存在的。
# - 对象就像一个塑料盒子，里面装的是数据。
# - 对象有不同类型，例如布尔型和整型，类型决定了可以对它进行的操作。
# - Python 中一个类型为int 的对象会告诉你：可以把它与另一个int 对象相加。

# %% [markdown]
# 对象的类型还决定了它装着的数据是允许被修改的变量（可变的）还是不可被修改的常量（不可变的）。
#
# Python 是强类型的（strongly typed），你永远无法修改一个已有对象的类型，即使它包含的值是可变的。

# %% [markdown]
# 在Python 中，我们用= 来给一个变量赋值。

# %%
a = 7

print(a)
#b = a
#print(b)
# Out:
# 7

# %% [markdown]
# 在Python 中，如果想知道一个对象（例如一个变量或者一个字面值）的类型，可以使用语句：type( thing )。试试对不同的字面值（58、99.9、abc）以及不同的变量（a、b）执行

# %%
type(a)
# Out:
# int

# %%
type(99.9)
# Out:
# float

# %%
type('abc')
# Out:
# str

# %% [markdown]
# 类（class）是对象的定义，第6 章会详细介绍。在Python 中，“类”和“类型”一般不加区分。
#
#
# 变量名只能包含以下字符：
#
# • 小写字母（a~z）
#
# • 大写字母（A~Z）
#
# • 数字（0~9）
#
# • 下划线（_）
#
# 名字不允许以数字开头。

# %% [markdown]
# 此外，Python 中以下划线开头的名字有特殊的含义（第4 章会解释）。下面是一些合法的名字：
# - a
# - a1
# - a_b_c___95
# - _abc
# - _1a
#
# 下面这些名字则是非法的：
# - 1
# - 1a
# - 1_
#
# 最后要注意的是，不要使用下面这些词作为变量名，它们是Python 保留的关键字：
# - False class finally is return
# - None continue for lambda try
# - True def from nonlocal while
# - and del global not with
# - as elif if or yield
# - assert else import pass
# - break except in raise

# %% [markdown]
# ### 2.2　数字

# %% [markdown]
# 2.2.1　整数
# 2.2.2　优先级
# 2.2.3　基数
# 2.2.4　类型转换
# 2.2.6　浮点数
# 2.2.7　数学函数

# %% [markdown]
# |运算符|描述|示例|运算结果|
# | -------- | -------- | -------- | -------- |
# |+ |加法|5 + 8| 13|
# |- |减法|90 – 10| 80|
# |* |乘法|4 * 7 |28|
# |/ |浮点数除法|7 / 2| 3.5|
# |// |整数除法|7 // 2 |3|
# |% |模（求余）| 7 % 3 |1|
# |** |幂|3 ** 4 |81|

# %% [markdown]
# #### 2.2.1　整数

# %% [markdown]
# 不允许数字以“0”开头

# %%
05
# Out:
#   Cell In[7], line 1
#     05
#     ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
a=5+9 + 3

# %% [markdown]
# • / 用来执行浮点除法（十进制小数）
# • // 用来执行整数除法（整除）

# %%
a

# %%
a = a - 3

# %%
divmod(9,5)
# Out:
# (1, 4)

# %% [markdown]
# #### 2.2.2　优先级

# %% [markdown]
# #### 2.2.3　基数

# %% [markdown]
# 在Python 中，整数默认使用十进制数（以10 为底），除非你在数字前添加前缀，显式地指
# 定使用其他基数（base）。
# • 0b 或0B 代表二进制（以2 为底）
# • 0o 或0O 代表八进制（以8 为底）
# • 0x 或0X 代表十六进制（以16 为底）

# %%
0b10
# Out:
# 2

# %%
0o10
# Out:
# 8

# %%
0x10
# Out:
# 16

# %% [markdown]
# #### 2.2.4　类型转换

# %%
int(True)
# Out:
# 1

# %%
int(98.6)
# Out:
# 98

# %% [markdown]
# int() 可以接受浮点数或由数字组成的字符串，但无法接受包含小数点或指数的字符串

# %% [markdown]
# 如果混合使用多种不同的数字类型进行计算，Python 会自动地进行类型转换：

# %%
4 + 7.0
# Out:
# 11.0

# %%
True + 2
# Out:
# 3

# %% [markdown]
# #### 2.2.5　一个int型有多大

# %% [markdown]
# 在Python 2 里，一个int 型包含32 位，可以存储从-2 147 483 648 到2 147 483 647 的整数。
#
# 一个long 型会占用更多的空间：64 位，可以存储从-9 223 372 036 854 775 808 到9 223 372 036 854 775 807 的整数。
#
# 到了Python 3，long 类型已不复存在，而int 类型变为可以存储任意大小的整数，甚至超过64 位。
#
# 因此，你可以进行像下面一样计算（10**100 被赋值给名为googol 的变量，这是Google 最初的名字，但由于其拼写困难而被现在的名字所取代）：

# %% [markdown]
# #### 2.2.6　浮点数

# %%
float(True)
# Out:
# 1.0

# %%
a =float('99')

# %% [markdown]
# ### 2.3　字符串

# %% [markdown]
# 字符串型是我们学习的第一个Python 序列类型，它的本质是字符序列。
#
# Python 字符串是不可变的。你无法对原字符串进行修改，但可以将字符串的一部分复制到新字符串，来达到相同的修改效果。
# - 2.3.1　使用引号创建
# - 2.3.2　使用str()进行类型转换
# - 2.3.3　使用\转义
# - 2.3.4　使用+拼接
# - 2.3.5　使用*复制
# - 2.3.6　使用[]提取字符
# - 2.3.7　使用[start:end:step]分片
# - 2.3.8　使用len()获得长度
# - 2.3.9　使用split()分割
# - 2.3.10　使用join()合并
# - 2.3.11　熟悉字符串
# - 2.3.12　大小写与对齐方式
# - 2.3.13　使用replace()替换

# %%
'Snap'

# %%
"Crackle"

# %%
"'Nay,' said the naysayer."

# %%
'''Boom!'''

# %%
poem = '''There was a Young Lady of Norway,
... Who casually sat in a doorway;
... When the door squeezed her flat,
... She exclaimed, "What of that?"
... This courageous Young Lady of Norway.'''

# %%
print(poem)

# %% [markdown]
# #### 2.3.2　使用str()进行类型转换

# %%
str(98.6)
# Out:
# '98.6'

# %%
str(1.0e4)
# Out:
# '10000.0'

# %%
str(True)
# Out:
# 'True'

# %% [markdown]
# #### 2.3.3　使用\转义

# %% [markdown]
# /n

# %%
palindrome = 'A man,\nA plan,\nA canal:\nPanama.'
print(palindrome)
# Out:
# A man,
# A plan,
# A canal:
# Panama.

# %%
print('\tabc')
# Out:
# 	abc

# %%
print('a\tbc')
# Out:
# a	bc

# %%
print('ab\tc')
# Out:
# ab	c

# %%
print('abc\t')
# Out:
# abc

# %%
testimony = "\"I did nothing!\" he said. \"Not that either! Or the other thing.\""

# %%
print(testimony)
# Out:
# "I did nothing!" he said. "Not that either! Or the other thing."

# %%
fact = "The world's largest rubber duck was 54'2\" by 65'7\" by 105'"

# %%
print(fact)
# Out:
# The world's largest rubber duck was 54'2" by 65'7" by 105'

# %%
speech = 'Today we honor our friend, the backslash: \\.'
print(speech)
# Out:
# Today we honor our friend, the backslash: \.

# %% [markdown]
# #### 2.3.4　使用+拼接

# %%
'Release the kraken! ' + 'At once!'
# Out:
# 'Release the kraken! At once!'

# %%
"My word! " "A gentleman caller!"
# Out:
# 'My word! A gentleman caller!'

# %%
a = 'Duck.'
b = a
c = 'Grey Duck!'
a + b + c
# Out:
# 'Duck.Duck.Grey Duck!'

# %%
print(a, b, c)
# Out:
# Duck. Duck. Grey Duck!

# %% [markdown]
# #### 2.3.5　使用*复制

# %%
start = 'Na ' * 4 + '\n'
middle = 'Hey ' * 3 + '\n'
end = 'Goodbye.'
print(start + start + middle + end)
# Out:
# Na Na Na Na
# Na Na Na Na
# Hey Hey Hey
# Goodbye.

# %% [markdown]
# #### 2.3.6　使用[]提取字符

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'
letters[0]
# Out:
# 'a'

# %%
letters[-2]
# Out:
# 'y'

# %% [markdown]
# #### 2.3.7　使用[start:end:step]分片

# %% [markdown]
# 分片操作（slice）可以从一个字符串中抽取子字符串（字符串的一部分）。我们使用一对方括号、起始偏移量start、终止偏移量end 以及可选的步长step 来定义一个分片。其中一些可以省略。
#
# 分片得到的子串包含从start 开始到end 之前的全部字符。
# - [:] 提取从开头到结尾的整个字符串
# - [start:] 从start 提取到结尾
# - [:end] 从开头提取到end - 1
# - [start:end] 从start 提取到end - 1
# - [start:end:step] 从start 提取到end - 1，每step 个字符提取一个

# %%
letters[:]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[20:]
# Out:
# 'uvwxyz'

# %%
letters[12:15]
# Out:
# 'mno'

# %%
letters[-3:]
# Out:
# 'xyz'

# %%
letters[18:-3]
# Out:
# 'stuvw'

# %%
letters[-6:-2]
# Out:
# 'uvwx'

# %%
letters[::2]
# Out:
# 'acegikmoqsuwy'

# %%
letters
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[-1::-1]
# Out:
# 'zyxwvutsrqponmlkjihgfedcba'

# %% [markdown]
# #### 2.3.8　使用len()获得长度

# %%
len(letters)
# Out:
# 26

# %% [markdown]
# #### 2.3.9　使用split()分割

# %% [markdown]
# string.function(arguments)
# 字符串函数split()
#
# split() 可以基于分隔符将字符串分割成由若干子串组成的列表

# %%
todos = 'get gloves,get mask,give cat vitamins,call ambulance'

# %%
todos.split(',')
# Out:
# ['get gloves', 'get mask', 'give cat vitamins', 'call ambulance']

# %% [markdown]
# #### 2.3.10　使用join()合并

# %%
crypto_list = ['Yeti', 'Bigfoot', 'Loch Ness Monster']

# %%
a ="..."

# %%
crypto_string = a.join(crypto_list)

# %%
print('Found and signing book deals:', crypto_string)
# Out:
# Found and signing book deals: Yeti...Bigfoot...Loch Ness Monster

# %% [markdown]
# #### 2.3.11　熟悉字符串

# %%
poem = '''All that doth flow we cannot liquid name
Or else would fire and water be the same;
But that is liquid which is moist and wet
Fire that property can never get.
Then 'tis not cold that doth the fire put out
But 'tis the wet that makes it die, no doubt.'''

# %%
poem[:13]
# Out:
# 'All that doth'

# %%
len(poem)
# Out:
# 250

# %%
poem.startswith('All')
# Out:
# False

# %%
poem.endswith('That\'s all, folks!')
# Out:
# False

# %%
word = 'the'
poem.find(word)
# Out:
# 73

# %%
poem.rfind(word)
# Out:
# 214

# %%
poem.count(word)
# Out:
# 3

# %%
poem.isalnum()
# Out:
# False

# %% [markdown]
# #### 2.3.12　大小写与对齐方式

# %%
setup = 'a duck goes into a bar...'

# %%
setup.strip('.')
# Out:
# 'a duck goes into a bar'

# %%
setup.capitalize()
# Out:
# 'A duck goes into a bar...'

# %%
setup.title()
# Out:
# 'A Duck Goes Into A Bar...'

# %%
setup.upper()
# Out:
# 'A DUCK GOES INTO A BAR...'

# %%
setup.lower()
# Out:
# 'a duck goes into a bar...'

# %%
setup.swapcase()
# Out:
# 'A DUCK GOES INTO A BAR...'

# %%
setup.center(30)
# Out:
# '  a duck goes into a bar...   '

# %%
setup.ljust(30)
# Out:
# 'a duck goes into a bar...     '

# %%
setup.rjust(30)
# Out:
# '     a duck goes into a bar...'

# %% [markdown]
# #### 2.3.13　使用replace()替换

# %% [markdown]
# 使用replace() 函数可以进行简单的子串替换。你需要传入的参数包括：需要被替换的子
# 串，用于替换的新子串，以及需要替换多少处。最后一个参数如果省略则默认只替换第一次出现的位置

# %%
setup.replace('duck', 'marmoset')
# Out:
# 'a marmoset goes into a bar...'

# %%
setup.replace('a ', 'a famous ', 100)
# Out:
# 'a famous duck goes into a famous bar...'

# %%
setup.replace('a', 'a famous', 100)

# %% [markdown]
# 有时，你可能想确保被替换的子串是一个完整的词，或者某一个词的开头，等等。在这种情况下，你需要借助正则表达式
